# %%
#文件导入
import numpy as np 
import cv2 
import os 
import matplotlib.pyplot as plt 
import time 
import os.path as osp 
import xml.etree.ElementTree as ET 
from matplotlib.colors import LogNorm

# %%
if False: # 调试
   # 读取图片
   num_IMG = 1

   fore_name =['OriRGB_pitaya_', 'RbRGB_pitaya_']
   image_name = fore_name[0]+ str(num_IMG).zfill(6)


   rootpath1 ='./VOC2007/JPEGImages/'
   image = cv2.imread( os.path.join(rootpath1, image_name +'.jpg'))        
   # image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)     
   # plt.rcParams[ 'figure.figsize' ] = [16, 6]                           
   # plt.imshow(image) 

   # 去除背景的图像
   rootpath_Rb = 'JPEGImages_Rb_HLGMulti/'
   image_name_Rb = fore_name[1]+ str(num_IMG).zfill(6)
   # print('image_name_Rb',image_name_Rb)
   # print('path',os.path.join(rootpath1, image_name_Rb +'.jpg'))
   image_Rb = cv2.imread( os.path.join(rootpath_Rb, image_name_Rb +'.jpg')) 
   # image2 = cv2.cvtColor(image_Rb, cv2.COLOR_BGR2RGB) 
   # plt.rcParams[ 'figure.figsize' ] = [16, 6]                           
   # plt.imshow(image2) 

   # 读取 xml 
   # 读取路径下的文件  
   rootpath2 = './VOC2007/Annotations/'
   xml_filepath = os.path.join(rootpath2, image_name +'.xml')       
   print(xml_filepath) 

   updateTree = ET.parse(xml_filepath)  # parse xml documents into element tree
   root = updateTree.getroot()      # return root element


   # dict - bbox - cls 
   rectangle_loc={ }
   class_name = ["NO", "OWF", "OF", "FCC", "OB"]
   for cls in class_name:
      rectangle_loc[cls] = []


   for obj in root.iter('object'):
      cls = obj.find('name').text

      if cls == 'NO':
         xmlbox = obj.find('bndbox') 
         b = (int(float(xmlbox.find('xmin').text)), int(float(xmlbox.find('ymin').text)), int(float(xmlbox.find('xmax').text)), int(float(xmlbox.find('ymax').text)))
         rectangle_loc['NO'].append(b)    

      elif cls == 'OWF':
         xmlbox = obj.find('bndbox') 
         b = (int(float(xmlbox.find('xmin').text)), int(float(xmlbox.find('ymin').text)), int(float(xmlbox.find('xmax').text)), int(float(xmlbox.find('ymax').text)))
         rectangle_loc['OWF'].append(b) 

      elif cls == 'OF':
         xmlbox = obj.find('bndbox') 
         b = (int(float(xmlbox.find('xmin').text)), int(float(xmlbox.find('ymin').text)), int(float(xmlbox.find('xmax').text)), int(float(xmlbox.find('ymax').text)))
         rectangle_loc['OF'].append(b)

      elif cls == 'FCC':
         xmlbox = obj.find('bndbox') 
         b = (int(float(xmlbox.find('xmin').text)), int(float(xmlbox.find('ymin').text)), int(float(xmlbox.find('xmax').text)), int(float(xmlbox.find('ymax').text)))
         rectangle_loc['FCC'].append(b) 

      elif cls == 'OB':
         xmlbox = obj.find('bndbox') 
         b = (int(float(xmlbox.find('xmin').text)), int(float(xmlbox.find('ymin').text)), int(float(xmlbox.find('xmax').text)), int(float(xmlbox.find('ymax').text)))
         rectangle_loc['OB'].append(b) 
      
      else:
         print( 'no target' ) 

   print(rectangle_loc)

# %%
if False: # 调试
    # opencv读取图片的默认像素排列是BGR = RGB
    # color_dict
    class_name = ["NO", "OWF", "OF", "FCC", "OB"]
    color_custom = [(255,0,0), (0,128,0), (0,0,255), (255,165,0), (128,0,128)]           # red = (255,0,0) | green=(0,128,0) | blue = (0,0,255) | Orange = (255,165,0) | Purple= (128,0,128)
    color_cls_dict ={ }

    for cls, col in zip(class_name, color_custom):
        # RGB ==> BGR
        col_BGR = [] # 清空
        col_RGB = list(col)
        col_BGR = [col_RGB[2], col_RGB[1] , col_RGB[0]]
        color_cls_dict[cls] = col_BGR
    print(color_cls_dict)


    # 绘制方框
    for key_cls, value_rectangle in rectangle_loc.items():
        print(key_cls, value_rectangle) 
    
        for i_num in range(len(value_rectangle)):
            xmin, ymin, xmax, ymax = value_rectangle[i_num]
            print('xmin, ymin, xmax, ymax == ', xmin, ymin, xmax, ymax )

            IMG_rec = cv2.rectangle(image, (xmin, ymin), (xmax, ymax), color_cls_dict[key_cls], 3)      # 画框,没有数据，
            IMG_rec_Rb = cv2.rectangle(image_Rb, (xmin, ymin), (xmax, ymax), color_cls_dict[key_cls], 3)
            
            
    floder_list = ['rectangle_box','rectangle_box_Rb']
    for floder in floder_list:
        if not os.path.isdir(floder):
            os.makedirs(floder)

    cv2.imwrite(floder_list[0] + '/'+ image_name + '_rectanglebox_img.jpg', IMG_rec)  
    cv2.imwrite(floder_list[1] + '/' + image_name_Rb + '_rectanglebox_img.jpg', IMG_rec_Rb)

# %%
## == 批量处理 ==##
# 读取图片
def Get_rectangle_loc(num_IMG = 1):
    fore_name =['OriRGB_pitaya_', 'RbRGB_pitaya_']
    image_name = fore_name[0]+ str(num_IMG).zfill(6)

    rootpath1 ='./VOC2007/JPEGImages/'
    image = cv2.imread( os.path.join(rootpath1, image_name +'.jpg'))        
    # image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)     
    # plt.rcParams[ 'figure.figsize' ] = [16, 6]                           
    # plt.imshow(image) 
    
    # 去除背景的图像
    rootpath_Rb = 'JPEGImages_Rb_HLGMulti/'
    image_name_Rb = fore_name[1]+ str(num_IMG).zfill(6)
    # print('image_name_Rb',image_name_Rb)
    # print('path',os.path.join(rootpath1, image_name_Rb +'.jpg'))
    image_Rb = cv2.imread( os.path.join(rootpath_Rb, image_name_Rb +'.jpg')) 
    # image2 = cv2.cvtColor(image_Rb, cv2.COLOR_BGR2RGB) 
    # plt.rcParams[ 'figure.figsize' ] = [16, 6]                           
    # plt.imshow(image2)    

    # 读取 xml 
    # 读取路径下的文件  
    rootpath2 = './VOC2007/Annotations/'
    xml_filepath = os.path.join(rootpath2, image_name +'.xml')       
    print(xml_filepath) 

    updateTree = ET.parse(xml_filepath)  # parse xml documents into element tree
    root = updateTree.getroot()      # return root element


    # dict - bbox - cls 
    rectangle_loc={ }
    class_name = ["NO", "OWF", "OF", "FCC", "OB"]
    for cls in class_name:
        rectangle_loc[cls] = []


    for obj in root.iter('object'):
        cls = obj.find('name').text

        if cls == 'NO':
            xmlbox = obj.find('bndbox') 
            b = (int(float(xmlbox.find('xmin').text)), int(float(xmlbox.find('ymin').text)), int(float(xmlbox.find('xmax').text)), int(float(xmlbox.find('ymax').text)))
            rectangle_loc['NO'].append(b)    

        elif cls == 'OWF':
            xmlbox = obj.find('bndbox') 
            b = (int(float(xmlbox.find('xmin').text)), int(float(xmlbox.find('ymin').text)), int(float(xmlbox.find('xmax').text)), int(float(xmlbox.find('ymax').text)))
            rectangle_loc['OWF'].append(b) 

        elif cls == 'OF':
            xmlbox = obj.find('bndbox') 
            b = (int(float(xmlbox.find('xmin').text)), int(float(xmlbox.find('ymin').text)), int(float(xmlbox.find('xmax').text)), int(float(xmlbox.find('ymax').text)))
            rectangle_loc['OF'].append(b)

        elif cls == 'FCC':
            xmlbox = obj.find('bndbox') 
            b = (int(float(xmlbox.find('xmin').text)), int(float(xmlbox.find('ymin').text)), int(float(xmlbox.find('xmax').text)), int(float(xmlbox.find('ymax').text)))
            rectangle_loc['FCC'].append(b) 

        elif cls == 'OB':
            xmlbox = obj.find('bndbox') 
            b = (int(float(xmlbox.find('xmin').text)), int(float(xmlbox.find('ymin').text)), int(float(xmlbox.find('xmax').text)), int(float(xmlbox.find('ymax').text)))
            rectangle_loc['OB'].append(b) 
        
        else:
            print( 'no target' ) 

    print(rectangle_loc, image_name, image_name_Rb)
    return rectangle_loc, image, image_name, image_Rb, image_name_Rb

Get_rectangle_loc(num_IMG = 1)
# Out:
# ./VOC2007/Annotations/OriRGB_pitaya_000001.xml
# {'NO': [], 'OWF': [], 'OF': [(274, 830, 404, 925), (403, 847, 480, 959)], 'FCC': [(480, 830, 585, 946)], 'OB': []} OriRGB_pitaya_000001 RbRGB_pitaya_000001
# ({'NO': [],
#   'OWF': [],
#   'OF': [(274, 830, 404, 925), (403, 847, 480, 959)],
#   'FCC': [(480, 830, 585, 946)],
#   'OB': []},
#  array([[[254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [211, 192, 187],
#          [191, 168, 166],
#          [183, 158, 156]],
#
#         [[254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [183, 164, 159],
#          [171, 150, 148],
#          [176, 153, 151]],
#
#         [[254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [169, 150, 145],
#          [164, 145, 140],
#          [164, 145, 140]],
#
#         ...,
#
#         [[ 38,  40,  48],
#          [ 36,  38,  46],
#          [ 35,  36,  46],
#          ...,
#          [ 80,  87, 114],
#          [ 85,  92, 119],
#          [ 86,  93, 118]],
#
#         [[ 40,  43,  48],
#          [ 40,  43,  48],
#          [ 40,  39,  48],
#          ...,
#          [ 84,  85, 113],
#          [ 89,  90, 118],
#          [ 92,  93, 121]],
#
#         [[ 41,  44,  49],
#          [ 42,  45,  50],
#          [ 42,  41,  50],
#          ...,
#          [ 89,  87, 117],
#          [ 89,  87, 116],
#          [ 90,  88, 117]]], dtype=uint8),
#  'OriRGB_pitaya_000001',
#  array([[[153, 153, 153],
#          [153, 153, 153],
#          [153, 153, 153],
#          ...,
#          [153, 153, 153],
#          [153, 153, 153],
#          [153, 153, 153]],
#
#         [[153, 153, 153],
#          [153, 153, 153],
#          [153, 153, 153],
#          ...,
#          [153, 153, 153],
#          [153, 153, 153],
#          [153, 153, 153]],
#
#         [[153, 153, 153],
#          [153, 153, 153],
#          [153, 153, 153],
#          ...,
#          [153, 153, 153],
#          [153, 153, 153],
#          [153, 153, 153]],
#
#         ...,
#
#         [[ 38,  40,  48],
#          [ 36,  38,  46],
#          [ 35,  36,  46],
#          ...,
#          [ 80,  87, 114],
#          [ 85,  92, 119],
#          [ 86,  93, 118]],
#
#         [[ 40,  43,  48],
#          [ 40,  43,  48],
#          [ 40,  39,  48],
#          ...,
#          [ 84,  85, 113],
#          [ 89,  90, 118],
#          [ 92,  93, 121]],
#
#         [[ 41,  44,  49],
#          [ 42,  45,  50],
#          [ 42,  41,  50],
#          ...,
#          [ 89,  87, 117],
#          [ 89,  87, 116],
#          [ 90,  88, 117]]], dtype=uint8),
#  'RbRGB_pitaya_000001')

# %%
def plot_rectanglebox(rectangle_loc, image, image_name, image_Rb, image_name_Rb):
    # opencv读取图片的默认像素排列是BGR = RGB
    # color_dict
    class_name = ["NO", "OWF", "OF", "FCC", "OB"]
    color_custom = [(255,0,0), (0,128,0), (0,0,255), (255,165,0), (128,0,128)]  # red = (255,0,0) | green=(0,128,0) | blue = (0,0,255) | Orange = (255,165,0) | Purple= (128,0,128)
    color_cls_dict ={ }

    for cls, col in zip(class_name, color_custom):
        # RGB ==> BGR
        col_BGR = [] # 清空
        col_RGB = list(col)
        col_BGR = [col_RGB[2], col_RGB[1] , col_RGB[0]]
        color_cls_dict[cls] = col_BGR
    # print(color_cls_dict)


    # 绘制方框
    for key_cls, value_rectangle in rectangle_loc.items():
        print(key_cls, value_rectangle) 
    
        for i_num in range(len(value_rectangle)):
            xmin, ymin, xmax, ymax = value_rectangle[i_num]
            print('xmin, ymin, xmax, ymax == ', xmin, ymin, xmax, ymax )

            IMG_rec = cv2.rectangle(image, (xmin, ymin), (xmax, ymax), color_cls_dict[key_cls], 3)      # 画框,没有数据，
            IMG_rec_Rb = cv2.rectangle(image_Rb, (xmin, ymin), (xmax, ymax), color_cls_dict[key_cls], 3)
            
    # IMG_rec_Rb1 = cv2.cvtColor(IMG_rec_Rb, cv2.COLOR_BGR2RGB) 
    # plt.imshow(IMG_rec_Rb1)        
    floder_list = ['rectangle_box','rectangle_box_Rb','results_rectangle/'+ image_name.split('.')[0][-6:]]
    for floder in floder_list:
        if not os.path.isdir(floder):
            os.makedirs(floder)


    print(floder_list[1] + '/' + image_name_Rb + '_rectanglebox_img.jpg')
    cv2.imwrite(floder_list[0] + '/'+ image_name + '_rectanglebox_img.jpg', IMG_rec)  
    cv2.imwrite(floder_list[1] + '/' + image_name_Rb + '_rectanglebox_img.jpg', IMG_rec_Rb) 

    #存到对应文件夹
    cv2.imwrite(floder_list[2] + '/'+ image_name + '_rectanglebox_img.jpg', IMG_rec)  
    cv2.imwrite(floder_list[2] + '/' + image_name_Rb + '_rectanglebox_img.jpg', IMG_rec_Rb)

# %%
num_IMG_find=[39, 140, 176, 252, 265, 344, 345, 362, 363, 443, 494, 571, 808, 927, 1058, 1217]

for num_IMG in num_IMG_find:
    rectangle_loc, image, image_name, image_Rb, image_name_Rb = Get_rectangle_loc(num_IMG = num_IMG)
    plot_rectanglebox(rectangle_loc, image = image, image_name= image_name, image_Rb=image_Rb, image_name_Rb=image_name_Rb)
    rectangle_loc, image, image_name = None, None, None #清空
# Out:
# ./VOC2007/Annotations/OriRGB_pitaya_000039.xml
# {'NO': [(1, 486, 71, 588)], 'OWF': [(345, 506, 488, 615)], 'OF': [(406, 1138, 480, 1238)], 'FCC': [(394, 1022, 518, 1139)], 'OB': [(202, 758, 272, 855), (280, 1030, 356, 1158)]} OriRGB_pitaya_000039 RbRGB_pitaya_000039
# NO [(1, 486, 71, 588)]
# xmin, ymin, xmax, ymax ==  1 486 71 588
# OWF [(345, 506, 488, 615)]
# xmin, ymin, xmax, ymax ==  345 506 488 615
# OF [(406, 1138, 480, 1238)]
# xmin, ymin, xmax, ymax ==  406 1138 480 1238
# FCC [(394, 1022, 518, 1139)]
# xmin, ymin, xmax, ymax ==  394 1022 518 1139
# OB [(202, 758, 272, 855), (280, 1030, 356, 1158)]
# xmin, ymin, xmax, ymax ==  202 758 272 855
# xmin, ymin, xmax, ymax ==  280 1030 356 1158
# rectangle_box_Rb/RbRGB_pitaya_000039_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000140.xml
# {'NO': [(519, 542, 648, 626)], 'OWF': [(87, 910, 241, 1043), (351, 699, 449, 792)], 'OF': [(381, 888, 441, 955)], 'FCC': [(304, 823, 426, 917)], 'OB': [(648, 776, 720, 870)]} OriRGB_pitaya_000140 RbRGB_pitaya_000140
# NO [(519, 542, 648, 626)]
# xmin, ymin, xmax, ymax ==  519 542 648 626
# OWF [(87, 910, 241, 1043), (351, 699, 449, 792)]
# xmin, ymin, xmax, ymax ==  87 910 241 1043
# xmin, ymin, xmax, ymax ==  351 699 449 792
# OF [(381, 888, 441, 955)]
# xmin, ymin, xmax, ymax ==  381 888 441 955
# FCC [(304, 823, 426, 917)]
# xmin, ymin, xmax, ymax ==  304 823 426 917
# OB [(648, 776, 720, 870)]
# xmin, ymin, xmax, ymax ==  648 776 720 870
# rectangle_box_Rb/RbRGB_pitaya_000140_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000176.xml
# {'NO': [(247, 1109, 347, 1221)], 'OWF': [(275, 462, 399, 579)], 'OF': [(655, 166, 720, 242)], 'FCC': [(669, 239, 720, 305)], 'OB': [(301, 939, 373, 1034)]} OriRGB_pitaya_000176 RbRGB_pitaya_000176
# NO [(247, 1109, 347, 1221)]
# xmin, ymin, xmax, ymax ==  247 1109 347 1221
# OWF [(275, 462, 399, 579)]
# xmin, ymin, xmax, ymax ==  275 462 399 579
# OF [(655, 166, 720, 242)]
# xmin, ymin, xmax, ymax ==  655 166 720 242
# FCC [(669, 239, 720, 305)]
# xmin, ymin, xmax, ymax ==  669 239 720 305
# OB [(301, 939, 373, 1034)]
# xmin, ymin, xmax, ymax ==  301 939 373 1034
# rectangle_box_Rb/RbRGB_pitaya_000176_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000252.xml
# {'NO': [(407, 667, 491, 754)], 'OWF': [(274, 1, 359, 90)], 'OF': [(542, 933, 675, 1026)], 'FCC': [(639, 973, 720, 1088)], 'OB': [(330, 1168, 414, 1254), (328, 1166, 412, 1252)]} OriRGB_pitaya_000252 RbRGB_pitaya_000252
# NO [(407, 667, 491, 754)]
# xmin, ymin, xmax, ymax ==  407 667 491 754
# OWF [(274, 1, 359, 90)]
# xmin, ymin, xmax, ymax ==  274 1 359 90
# OF [(542, 933, 675, 1026)]
# xmin, ymin, xmax, ymax ==  542 933 675 1026
# FCC [(639, 973, 720, 1088)]
# xmin, ymin, xmax, ymax ==  639 973 720 1088
# OB [(330, 1168, 414, 1254), (328, 1166, 412, 1252)]
# xmin, ymin, xmax, ymax ==  330 1168 414 1254
# xmin, ymin, xmax, ymax ==  328 1166 412 1252
# rectangle_box_Rb/RbRGB_pitaya_000252_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000265.xml
# {'NO': [(1, 357, 30, 417), (1, 769, 33, 837), (1, 866, 119, 955), (554, 1055, 657, 1156)], 'OWF': [(427, 238, 506, 325)], 'OF': [(1, 1045, 92, 1129)], 'FCC': [(63, 1071, 142, 1166)], 'OB': [(310, 254, 398, 318)]} OriRGB_pitaya_000265 RbRGB_pitaya_000265
# NO [(1, 357, 30, 417), (1, 769, 33, 837), (1, 866, 119, 955), (554, 1055, 657, 1156)]
# xmin, ymin, xmax, ymax ==  1 357 30 417
# xmin, ymin, xmax, ymax ==  1 769 33 837
# xmin, ymin, xmax, ymax ==  1 866 119 955
# xmin, ymin, xmax, ymax ==  554 1055 657 1156
# OWF [(427, 238, 506, 325)]
# xmin, ymin, xmax, ymax ==  427 238 506 325
# OF [(1, 1045, 92, 1129)]
# xmin, ymin, xmax, ymax ==  1 1045 92 1129
# FCC [(63, 1071, 142, 1166)]
# xmin, ymin, xmax, ymax ==  63 1071 142 1166
# OB [(310, 254, 398, 318)]
# xmin, ymin, xmax, ymax ==  310 254 398 318
# rectangle_box_Rb/RbRGB_pitaya_000265_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000344.xml
# {'NO': [(121, 864, 197, 938)], 'OWF': [(342, 27, 426, 150)], 'OF': [(17, 130, 99, 219)], 'FCC': [(1, 207, 50, 288)], 'OB': [(17, 726, 60, 797)]} OriRGB_pitaya_000344 RbRGB_pitaya_000344
# NO [(121, 864, 197, 938)]
# xmin, ymin, xmax, ymax ==  121 864 197 938
# OWF [(342, 27, 426, 150)]
# xmin, ymin, xmax, ymax ==  342 27 426 150
# OF [(17, 130, 99, 219)]
# xmin, ymin, xmax, ymax ==  17 130 99 219
# FCC [(1, 207, 50, 288)]
# xmin, ymin, xmax, ymax ==  1 207 50 288
# OB [(17, 726, 60, 797)]
# xmin, ymin, xmax, ymax ==  17 726 60 797
# rectangle_box_Rb/RbRGB_pitaya_000344_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000345.xml
# {'NO': [(509, 863, 598, 937)], 'OWF': [(371, 793, 437, 867)], 'OF': [(422, 133, 479, 217)], 'FCC': [(393, 216, 478, 294)], 'OB': [(333, 727, 370, 814)]} OriRGB_pitaya_000345 RbRGB_pitaya_000345
# NO [(509, 863, 598, 937)]
# xmin, ymin, xmax, ymax ==  509 863 598 937
# OWF [(371, 793, 437, 867)]
# xmin, ymin, xmax, ymax ==  371 793 437 867
# OF [(422, 133, 479, 217)]
# xmin, ymin, xmax, ymax ==  422 133 479 217
# FCC [(393, 216, 478, 294)]
# xmin, ymin, xmax, ymax ==  393 216 478 294
# OB [(333, 727, 370, 814)]
# xmin, ymin, xmax, ymax ==  333 727 370 814
# rectangle_box_Rb/RbRGB_pitaya_000345_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000362.xml
# {'NO': [(1, 1112, 65, 1224), (565, 707, 678, 782)], 'OWF': [(199, 898, 299, 962)], 'OF': [(243, 795, 321, 866)], 'FCC': [(221, 712, 306, 804)], 'OB': [(51, 469, 158, 525), (335, 941, 413, 989), (582, 807, 674, 895)]} OriRGB_pitaya_000362 RbRGB_pitaya_000362
# NO [(1, 1112, 65, 1224), (565, 707, 678, 782)]
# xmin, ymin, xmax, ymax ==  1 1112 65 1224
# xmin, ymin, xmax, ymax ==  565 707 678 782
# OWF [(199, 898, 299, 962)]
# xmin, ymin, xmax, ymax ==  199 898 299 962
# OF [(243, 795, 321, 866)]
# xmin, ymin, xmax, ymax ==  243 795 321 866
# FCC [(221, 712, 306, 804)]
# xmin, ymin, xmax, ymax ==  221 712 306 804
# OB [(51, 469, 158, 525), (335, 941, 413, 989), (582, 807, 674, 895)]
# xmin, ymin, xmax, ymax ==  51 469 158 525
# xmin, ymin, xmax, ymax ==  335 941 413 989
# xmin, ymin, xmax, ymax ==  582 807 674 895
# rectangle_box_Rb/RbRGB_pitaya_000362_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000363.xml
# {'NO': [(1, 450, 85, 526), (345, 1137, 429, 1280)], 'OWF': [(526, 914, 643, 991)], 'OF': [(591, 809, 671, 875)], 'FCC': [(562, 723, 658, 815)], 'OB': [(342, 485, 449, 551), (662, 947, 720, 1000)]} OriRGB_pitaya_000363 RbRGB_pitaya_000363
# NO [(1, 450, 85, 526), (345, 1137, 429, 1280)]
# xmin, ymin, xmax, ymax ==  1 450 85 526
# xmin, ymin, xmax, ymax ==  345 1137 429 1280
# OWF [(526, 914, 643, 991)]
# xmin, ymin, xmax, ymax ==  526 914 643 991
# OF [(591, 809, 671, 875)]
# xmin, ymin, xmax, ymax ==  591 809 671 875
# FCC [(562, 723, 658, 815)]
# xmin, ymin, xmax, ymax ==  562 723 658 815
# OB [(342, 485, 449, 551), (662, 947, 720, 1000)]
# xmin, ymin, xmax, ymax ==  342 485 449 551
# xmin, ymin, xmax, ymax ==  662 947 720 1000
# rectangle_box_Rb/RbRGB_pitaya_000363_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000443.xml
# {'NO': [(88, 468, 216, 583), (567, 1130, 719, 1276)], 'OWF': [(202, 253, 328, 396)], 'OF': [(51, 991, 161, 1099)], 'FCC': [(79, 1087, 207, 1202), (579, 995, 706, 1089)], 'OB': [(589, 878, 709, 995)]} OriRGB_pitaya_000443 RbRGB_pitaya_000443
# NO [(88, 468, 216, 583), (567, 1130, 719, 1276)]
# xmin, ymin, xmax, ymax ==  88 468 216 583
# xmin, ymin, xmax, ymax ==  567 1130 719 1276
# OWF [(202, 253, 328, 396)]
# xmin, ymin, xmax, ymax ==  202 253 328 396
# OF [(51, 991, 161, 1099)]
# xmin, ymin, xmax, ymax ==  51 991 161 1099
# FCC [(79, 1087, 207, 1202), (579, 995, 706, 1089)]
# xmin, ymin, xmax, ymax ==  79 1087 207 1202
# xmin, ymin, xmax, ymax ==  579 995 706 1089
# OB [(589, 878, 709, 995)]
# xmin, ymin, xmax, ymax ==  589 878 709 995
# rectangle_box_Rb/RbRGB_pitaya_000443_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000494.xml
# {'NO': [(105, 1167, 223, 1280)], 'OWF': [(216, 841, 311, 940)], 'OF': [(608, 684, 688, 792)], 'FCC': [(534, 684, 637, 795)], 'OB': [(62, 695, 169, 797)]} OriRGB_pitaya_000494 RbRGB_pitaya_000494
# NO [(105, 1167, 223, 1280)]
# xmin, ymin, xmax, ymax ==  105 1167 223 1280
# OWF [(216, 841, 311, 940)]
# xmin, ymin, xmax, ymax ==  216 841 311 940
# OF [(608, 684, 688, 792)]
# xmin, ymin, xmax, ymax ==  608 684 688 792
# FCC [(534, 684, 637, 795)]
# xmin, ymin, xmax, ymax ==  534 684 637 795
# OB [(62, 695, 169, 797)]
# xmin, ymin, xmax, ymax ==  62 695 169 797
# rectangle_box_Rb/RbRGB_pitaya_000494_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000571.xml
# {'NO': [(351, 751, 469, 829)], 'OWF': [(451, 563, 551, 635)], 'OF': [(1, 1051, 64, 1132)], 'FCC': [(9, 950, 107, 1057)], 'OB': [(199, 716, 301, 798), (207, 811, 303, 881)]} OriRGB_pitaya_000571 RbRGB_pitaya_000571
# NO [(351, 751, 469, 829)]
# xmin, ymin, xmax, ymax ==  351 751 469 829
# OWF [(451, 563, 551, 635)]
# xmin, ymin, xmax, ymax ==  451 563 551 635
# OF [(1, 1051, 64, 1132)]
# xmin, ymin, xmax, ymax ==  1 1051 64 1132
# FCC [(9, 950, 107, 1057)]
# xmin, ymin, xmax, ymax ==  9 950 107 1057
# OB [(199, 716, 301, 798), (207, 811, 303, 881)]
# xmin, ymin, xmax, ymax ==  199 716 301 798
# xmin, ymin, xmax, ymax ==  207 811 303 881
# rectangle_box_Rb/RbRGB_pitaya_000571_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000808.xml
# {'NO': [(79, 427, 237, 538)], 'OWF': [(329, 657, 387, 727)], 'OF': [(165, 643, 263, 707)], 'FCC': [(235, 670, 310, 745), (526, 577, 628, 658)], 'OB': [(327, 557, 407, 631), (467, 557, 545, 617), (459, 772, 538, 836)]} OriRGB_pitaya_000808 RbRGB_pitaya_000808
# NO [(79, 427, 237, 538)]
# xmin, ymin, xmax, ymax ==  79 427 237 538
# OWF [(329, 657, 387, 727)]
# xmin, ymin, xmax, ymax ==  329 657 387 727
# OF [(165, 643, 263, 707)]
# xmin, ymin, xmax, ymax ==  165 643 263 707
# FCC [(235, 670, 310, 745), (526, 577, 628, 658)]
# xmin, ymin, xmax, ymax ==  235 670 310 745
# xmin, ymin, xmax, ymax ==  526 577 628 658
# OB [(327, 557, 407, 631), (467, 557, 545, 617), (459, 772, 538, 836)]
# xmin, ymin, xmax, ymax ==  327 557 407 631
# xmin, ymin, xmax, ymax ==  467 557 545 617
# xmin, ymin, xmax, ymax ==  459 772 538 836
# rectangle_box_Rb/RbRGB_pitaya_000808_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_000927.xml
# {'NO': [(496, 643, 590, 760), (1, 524, 23, 592)], 'OWF': [(138, 949, 222, 1022)], 'OF': [(94, 831, 191, 907)], 'FCC': [(170, 827, 274, 908)], 'OB': [(337, 845, 422, 923)]} OriRGB_pitaya_000927 RbRGB_pitaya_000927
# NO [(496, 643, 590, 760), (1, 524, 23, 592)]
# xmin, ymin, xmax, ymax ==  496 643 590 760
# xmin, ymin, xmax, ymax ==  1 524 23 592
# OWF [(138, 949, 222, 1022)]
# xmin, ymin, xmax, ymax ==  138 949 222 1022
# OF [(94, 831, 191, 907)]
# xmin, ymin, xmax, ymax ==  94 831 191 907
# FCC [(170, 827, 274, 908)]
# xmin, ymin, xmax, ymax ==  170 827 274 908
# OB [(337, 845, 422, 923)]
# xmin, ymin, xmax, ymax ==  337 845 422 923
# rectangle_box_Rb/RbRGB_pitaya_000927_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_001058.xml
# {'NO': [(1, 814, 53, 901), (693, 921, 720, 975)], 'OWF': [(54, 973, 145, 1067), (594, 687, 669, 770)], 'OF': [(379, 861, 475, 947)], 'FCC': [(309, 895, 397, 991)], 'OB': [(550, 306, 629, 411)]} OriRGB_pitaya_001058 RbRGB_pitaya_001058
# NO [(1, 814, 53, 901), (693, 921, 720, 975)]
# xmin, ymin, xmax, ymax ==  1 814 53 901
# xmin, ymin, xmax, ymax ==  693 921 720 975
# OWF [(54, 973, 145, 1067), (594, 687, 669, 770)]
# xmin, ymin, xmax, ymax ==  54 973 145 1067
# xmin, ymin, xmax, ymax ==  594 687 669 770
# OF [(379, 861, 475, 947)]
# xmin, ymin, xmax, ymax ==  379 861 475 947
# FCC [(309, 895, 397, 991)]
# xmin, ymin, xmax, ymax ==  309 895 397 991
# OB [(550, 306, 629, 411)]
# xmin, ymin, xmax, ymax ==  550 306 629 411
# rectangle_box_Rb/RbRGB_pitaya_001058_rectanglebox_img.jpg
# ./VOC2007/Annotations/OriRGB_pitaya_001217.xml
# {'NO': [(1, 761, 37, 816), (1, 825, 29, 884)], 'OWF': [(66, 753, 210, 886)], 'OF': [(426, 863, 539, 973), (399, 973, 511, 1063)], 'FCC': [(363, 778, 486, 878)], 'OB': [(291, 415, 398, 533)]} OriRGB_pitaya_001217 RbRGB_pitaya_001217
# NO [(1, 761, 37, 816), (1, 825, 29, 884)]
# xmin, ymin, xmax, ymax ==  1 761 37 816
# xmin, ymin, xmax, ymax ==  1 825 29 884
# OWF [(66, 753, 210, 886)]
# xmin, ymin, xmax, ymax ==  66 753 210 886
# OF [(426, 863, 539, 973), (399, 973, 511, 1063)]
# xmin, ymin, xmax, ymax ==  426 863 539 973
# xmin, ymin, xmax, ymax ==  399 973 511 1063
# FCC [(363, 778, 486, 878)]
# xmin, ymin, xmax, ymax ==  363 778 486 878
# OB [(291, 415, 398, 533)]
# xmin, ymin, xmax, ymax ==  291 415 398 533
# rectangle_box_Rb/RbRGB_pitaya_001217_rectanglebox_img.jpg

# %%
# 深度图像 
num_IMG_find=[39, 140, 176, 252, 265, 344, 345, 362, 363, 443, 494, 571, 808, 927, 1058, 1217]
rootpath_depthimage = 'DepthImages_npy_Sort/'
savepath_depthimage = 'DepthImages_img/' 

for num_IMG in num_IMG_find:
   deep_image_npy = np.load(file = rootpath_depthimage +'depth_pitaya_'+ str(num_IMG).zfill(6) +'.npy')    # 加载npy文件
   deep_image_npy_cMAP = cv2.applyColorMap(cv2.convertScaleAbs(deep_image_npy, alpha=0.03), cv2.COLORMAP_JET) #伪彩图

   floder_list = [ savepath_depthimage,'results_rectangle/'+ str(num_IMG).zfill(6) ]
   for floder in floder_list:
      if not os.path.isdir(floder):
         os.makedirs(floder)

   cv2.imwrite( savepath_depthimage + 'depth_pitaya_' + str(num_IMG).zfill(6)+'.jpg', deep_image_npy_cMAP) # 保存图像数据
   # 存到对应文件夹
   cv2.imwrite(floder_list[1] + '/'+ 'depth_pitaya_' + str(num_IMG).zfill(6)+'.jpg', deep_image_npy_cMAP)
